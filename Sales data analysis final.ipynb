# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\BDM Project 1\\final sales data")

# %%
df.head()
# Out:
#    Unnamed: 0   Bill Date Bill Number             BillTime  Customer Code  \
# 0           0  2024-01-01   C01008600  Jan  1 2024  8:04AM            1.0
# 1           1  2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 2           2  2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 3           3  2024-01-01   C01008602  Jan  1 2024  9:47AM           18.0
# 4           4  2024-01-01   C01008603  Jan  1 2024 10:16AM           18.0
#
#          Customer Name  No Of Days  Product Code              Product Name  \
# 0  THIRUCHENDUR MURUGA       182.0        3605.0              RANTAC 150MG
# 1            MR.YUVESH       182.0       38752.0         PARACIP 650MG TAB
# 2            MR.YUVESH       182.0       12290.0                  VICKS 5G
# 3             MR.VIJAY       182.0        3515.0            GLUCORED FORTE
# 4             MR.VIJAY       182.0         214.0  HYDROGEN PEROXIDE  100ML
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Bill Date', 'Bill Number', 'BillTime', 'Customer Code',
#        'Customer Name', 'No Of Days', 'Product Code', 'Product Name',
#        'Quantity', 'Bill Amount', 'Discount Percentage', 'Discount Amount',
#        'Overall Discount Amount', 'MRP', 'Gross Amount With Discount',
#        'Overall Discount Percentage', 'Net Amount', 'Gross Before Discount',
#        'Sale Unit', 'Purchase Unit', 'Purchase Price', 'MRP Value', 'UnitRate',
#        'Mth', 'Yr', 'Profit'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'], axis=1)
# Out:
#         Bill Date Bill Number             BillTime  Customer Code  \
# 0      2024-01-01   C01008600  Jan  1 2024  8:04AM            1.0
# 1      2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 2      2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 3      2024-01-01   C01008602  Jan  1 2024  9:47AM           18.0
# 4      2024-01-01   C01008603  Jan  1 2024 10:16AM           18.0
# ...           ...         ...                  ...            ...
# 27660  2024-06-30   C01023406  Jun 30 2024 10:22PM           37.0
# 27661  2024-06-30   C01023407  Jun 30 2024 10:38PM           23.0
# 27662  2024-06-30   C01023408  Jun 30 2024 10:50PM         1679.0
# 27663  2024-06-30   C01023408  Jun 30 2024 10:50PM         1679.0
# 27664  2024-06-30   C01023409  Jun 30 2024 10:54PM            1.0
#
#              Customer Name  No Of Days  Product Code  \
# 0      THIRUCHENDUR MURUGA       182.0        3605.0
# 1                MR.YUVESH       182.0       38752.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Bill Date Bill Number             BillTime  Customer Code  \
# 0           0  2024-01-01   C01008600  Jan  1 2024  8:04AM            1.0
# 1           1  2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 2           2  2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 3           3  2024-01-01   C01008602  Jan  1 2024  9:47AM           18.0
# 4           4  2024-01-01   C01008603  Jan  1 2024 10:16AM           18.0
#
#          Customer Name  No Of Days  Product Code              Product Name  \
# 0  THIRUCHENDUR MURUGA       182.0        3605.0              RANTAC 150MG
# 1            MR.YUVESH       182.0       38752.0         PARACIP 650MG TAB
# 2            MR.YUVESH       182.0       12290.0                  VICKS 5G
# 3             MR.VIJAY       182.0        3515.0            GLUCORED FORTE
# 4             MR.VIJAY       182.0         214.0  HYDROGEN PEROXIDE  100ML
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27665 entries, 0 to 27664
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   27665 non-null  int64
#  1   Bill Date                    27665 non-null  object
#  2   Bill Number                  27665 non-null  object
#  3   BillTime                     27665 non-null  object
#  4   Customer Code                27665 non-null  float64
#  5   Customer Name                26801 non-null  object
#  6   No Of Days                   27665 non-null  float64
#  7   Product Code                 27665 non-null  float64
#  8   Product Name                 27665 non-null  object
#  9   Quantity                     27665 non-null  int64
#  10  Bill Amount                  27665 non-null  int64
#  11  Discount Percentage          27665 non-null  float64
#  12  Discount Amount              27665 non-null  float64
# ...

# %%
df['Profit'] = df['Net Amount'] - df['Purchase Price']

# Step 2: Calculate Profit Margin
df['Profit Margin'] = (df['Profit'] / df['Net Amount']) * 100

# %%
df.head()
# Out:
#    Unnamed: 0   Bill Date Bill Number             BillTime  Customer Code  \
# 0           0  2024-01-01   C01008600  Jan  1 2024  8:04AM            1.0
# 1           1  2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 2           2  2024-01-01   C01008601  Jan  1 2024  8:29AM            0.0
# 3           3  2024-01-01   C01008602  Jan  1 2024  9:47AM           18.0
# 4           4  2024-01-01   C01008603  Jan  1 2024 10:16AM           18.0
#
#          Customer Name  No Of Days  Product Code              Product Name  \
# 0  THIRUCHENDUR MURUGA       182.0        3605.0              RANTAC 150MG
# 1            MR.YUVESH       182.0       38752.0         PARACIP 650MG TAB
# 2            MR.YUVESH       182.0       12290.0                  VICKS 5G
# 3             MR.VIJAY       182.0        3515.0            GLUCORED FORTE
# 4             MR.VIJAY       182.0         214.0  HYDROGEN PEROXIDE  100ML
#
#    Quantity  ...  Gross Before Discount  Sale Unit  Purchase Unit  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataframe is named df
df['Bill Date'] = pd.to_datetime(df['Bill Date'])  # Ensure 'Bill Date' is in datetime format

# Create a new column 'Month-Year' for grouping by month
df['Month-Year'] = df['Bill Date'].dt.to_period('M')  # This will give 'YYYY-MM' format

# Group by 'Month-Year' and sum the 'Profit' for each month
monthly_profit = df.groupby('Month-Year')['Profit'].sum()

# Plot the bar chart
plt.figure(figsize=(10, 6))
monthly_profit.plot(kind='bar', color='green')
plt.title('Monthly Profit')
plt.xlabel('Month-Year')
plt.ylabel('Total Profit')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensure labels don't get cut off
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataframe is named df
df['Bill Date'] = pd.to_datetime(df['Bill Date'])  # Ensure 'Bill Date' is in datetime format

# Group by 'Bill Date' and sum the 'Profit' for each day
daily_profit = df.groupby('Bill Date')['Profit'].sum()

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(daily_profit, bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Daily Profits')
plt.xlabel('Profit')
plt.ylabel('Frequency (Number of Days)')
plt.grid(True)
plt.tight_layout()  # Ensure layout doesn't get cut off
plt.show()

# %%
# Sales Trend Line Plot
df['Bill Date'] = pd.to_datetime(df['Bill Date'])
df.set_index('Bill Date', inplace=True)
monthly_sales = df['Net Amount'].resample('M').sum()

plt.figure(figsize=(10,6))
plt.plot(monthly_sales, label='Monthly Sales')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Bar plot for total sales by product
product_sales = df.groupby('Product Name')['Net Amount'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
product_sales.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Products by Sales')
plt.ylabel('Sales Amount')
plt.xticks(rotation=90)
plt.show()

# %%
# Scatter plot for sales vs profit
plt.figure(figsize=(8,6))
sns.scatterplot(x='Net Amount', y='Profit', data=df)
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.grid(True)
plt.show()

# %%
# Heatmap of correlations between variables
plt.figure(figsize=(10,6))
corr = df[['Net Amount', 'Profit', 'Discount Amount', 'Quantity']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Pie chart of sales by top customers
customer_sales = df.groupby('Customer Name')['Net Amount'].sum().sort_values(ascending=False)

plt.figure(figsize=(8,8))
plt.pie(customer_sales.head(10), labels=customer_sales.head(10).index, autopct='%1.1f%%', startangle=140)

plt.title('Top 10 Customers by Sales')
plt.show()

# %%
# Pair plot of numerical columns
sns.pairplot(df[['Net Amount', 'Profit', 'Discount Amount', 'Quantity']])
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Area plot for cumulative sales over time
plt.figure(figsize=(10,6))
monthly_sales.cumsum().plot(kind='area', color='lightblue', alpha=0.5)
plt.title('Cumulative Monthly Sales')
plt.ylabel('Cumulative Sales')
plt.show()

# %%
# Count plot for the number of transactions by product
plt.figure(figsize=(12,6))
sns.countplot(x='Product Name', data=df, order=df['Product Name'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Transaction Count per Product')
plt.show()

# %%
from pandas.plotting import lag_plot

# Lag plot for sales to find patterns over time
plt.figure(figsize=(8,6))
lag_plot(monthly_sales)
plt.title('Lag Plot of Sales')
plt.show()

# %%
product_sales = df['Product Name'].value_counts()

plt.figure(figsize=(10,6))
product_sales.plot(kind='bar')
plt.title('Sales Count by Product')
plt.xlabel('Product Name')
plt.ylabel('Count')
plt.show()

# %%
most_purchased_product = df['Product Name'].mode()[0]
print("Most Purchased Product:", most_purchased_product)
# Out:
# Most Purchased Product: NICIP COLD & FLU TAB

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.index, df['Profit'], color='blue', alpha=0.5)

plt.title('Scatter Plot of Profit')
plt.xlabel('Index')
plt.ylabel('Profit')

plt.show()

# %%
df.describe()
# Out:
#          Unnamed: 0  Customer Code    No Of Days  Product Code      Quantity  \
# count  27665.000000   27665.000000  27665.000000  27665.000000  27665.000000
# mean   15233.915127     357.425122     95.734827  27585.542527      4.547587
# std     8873.929153     513.387087     53.965811  13890.296085      6.748545
# min        0.000000       0.000000      1.000000      8.000000    -30.000000
# 25%     7543.000000       9.000000     48.000000  16659.000000      1.000000
# 50%    15148.000000      46.000000    101.000000  37195.000000      2.000000
# 75%    22885.000000     709.000000    143.000000  38318.000000      4.000000
# max    30730.000000    1807.000000    182.000000  39615.000000    170.000000
#
#         Bill Amount  Discount Percentage  Discount Amount  \
# count  27665.000000         27665.000000     27665.000000
# mean      55.991686             7.743112         4.656812
# std      176.646476             3.749608         5.657830
# ...

# %%
df.head()
# Out:
#             Unnamed: 0 Bill Number             BillTime  Customer Code  \
# Bill Date
# 2024-01-01           0   C01008600  Jan  1 2024  8:04AM            1.0
# 2024-01-01           1   C01008601  Jan  1 2024  8:29AM            0.0
# 2024-01-01           2   C01008601  Jan  1 2024  8:29AM            0.0
# 2024-01-01           3   C01008602  Jan  1 2024  9:47AM           18.0
# 2024-01-01           4   C01008603  Jan  1 2024 10:16AM           18.0
#
#                   Customer Name  No Of Days  Product Code  \
# Bill Date
# 2024-01-01  THIRUCHENDUR MURUGA       182.0        3605.0
# 2024-01-01            MR.YUVESH       182.0       38752.0
# 2024-01-01            MR.YUVESH       182.0       12290.0
# 2024-01-01             MR.VIJAY       182.0        3515.0
# 2024-01-01             MR.VIJAY       182.0         214.0
#
#                         Product Name  Quantity  Bill Amount  ...  Sale Unit  \
# Bill Date                                                    ...
# ...

# %%
df.tail()
# Out:
#             Unnamed: 0 Bill Number             BillTime  Customer Code  \
# Bill Date
# 2024-06-30       30725   C01023406  Jun 30 2024 10:22PM           37.0
# 2024-06-30       30726   C01023407  Jun 30 2024 10:38PM           23.0
# 2024-06-30       30727   C01023408  Jun 30 2024 10:50PM         1679.0
# 2024-06-30       30728   C01023408  Jun 30 2024 10:50PM         1679.0
# 2024-06-30       30730   C01023409  Jun 30 2024 10:54PM            1.0
#
#                   Customer Name  No Of Days  Product Code  \
# Bill Date
# 2024-06-30           MRS.SEETHA         1.0       28304.0
# 2024-06-30              MR.GIJU         1.0       37155.0
# 2024-06-30         MR.ELANKOVAN         1.0       38178.0
# 2024-06-30         MR.ELANKOVAN         1.0        1483.0
# 2024-06-30  THIRUCHENDUR MURUGA         1.0       38858.0
#
#                     Product Name  Quantity  Bill Amount  ...  Sale Unit  \
# Bill Date                                                ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Bill Number', 'BillTime', 'Customer Code',
#        'Customer Name', 'No Of Days', 'Product Code', 'Product Name',
#        'Quantity', 'Bill Amount', 'Discount Percentage', 'Discount Amount',
#        'Overall Discount Amount', 'MRP', 'Gross Amount With Discount',
#        'Overall Discount Percentage', 'Net Amount', 'Gross Before Discount',
#        'Sale Unit', 'Purchase Unit', 'Purchase Price', 'MRP Value', 'UnitRate',
#        'Mth', 'Yr', 'Profit', 'Profit Margin', 'Month-Year'],
#       dtype='object')

# %%
loss = df[df["Profit"] <=0]

# %%
loss
# Out:
#             Unnamed: 0 Bill Number             BillTime  Customer Code  \
# Bill Date
# 2024-01-01           0   C01008600  Jan  1 2024  8:04AM            1.0
# 2024-01-01           1   C01008601  Jan  1 2024  8:29AM            0.0
# 2024-01-01           5   C01008603  Jan  1 2024 10:16AM           18.0
# 2024-01-01           6   C01008603  Jan  1 2024 10:16AM           18.0
# 2024-01-01           7   C01008603  Jan  1 2024 10:16AM           18.0
# ...                ...         ...                  ...            ...
# 2024-06-30       30719   C01023404  Jun 30 2024 10:00PM            0.0
# 2024-06-30       30720   C01023405  Jun 30 2024 10:13PM           46.0
# 2024-06-30       30721   C01023405  Jun 30 2024 10:13PM           46.0
# 2024-06-30       30722   C01023405  Jun 30 2024 10:13PM           46.0
# 2024-06-30       30723   C01023405  Jun 30 2024 10:13PM           46.0
#
#                   Customer Name  No Of Days  Product Code       Product Name  \
# Bill Date
# ...

# %%
df.shape
# Out:
# (27665, 28)

# %%
loss.shape
# Out:
# (10778, 28)

# %%
loss.describe()
# Out:
#          Unnamed: 0  Customer Code    No Of Days  Product Code      Quantity  \
# count  10778.000000   10778.000000  10778.000000  10778.000000  10778.000000
# mean   15058.807478     299.499536     96.676099  26502.388569      3.029690
# std     9008.137642     467.126183     54.719201  14405.610941      3.716307
# min        0.000000       0.000000      1.000000     38.000000    -30.000000
# 25%     7061.250000      13.000000     48.000000  12963.000000      2.000000
# 50%    15003.500000      38.000000    102.000000  37195.000000      2.000000
# 75%    22972.750000     508.000000    145.000000  38591.000000      3.000000
# max    30723.000000    1806.000000    182.000000  39611.000000    120.000000
#
#         Bill Amount  Discount Percentage  Discount Amount  \
# count  10778.000000         10778.000000     10778.000000
# mean      24.451011             8.313472         1.680663
# std       91.595361             3.654635         2.153684
# ...

# %%
plt.figure(figsize=(10,6))

sns.histplot(loss['Profit'], bins=30,color='red',kde=True)
plt.title("Distribution of Loss-Making Sales Profit")
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
profit = df[df["Profit"] > 0]

plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
sns.histplot(profit['Profit'], bins=30, color='green', kde=True)
plt.title('Distribution of Profit-Making Sales Profits')
plt.xlabel('Profit')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
sns.histplot(loss['Profit'], bins=30, color='yellow', kde=True)
plt.title('Distribution of Loss-Making Sales Profits')
plt.xlabel('Loss')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
loss_by_product = loss['Product Name'].value_counts().head(20)

plt.figure(figsize=(12,6))

loss_by_product.plot(kind='bar', color='orange')
plt.title('Top 10 Products with Most Loss-Making Sales')
plt.xlabel('Product Name')
plt.ylabel('Number of Loss-Making Sales')
plt.xticks(rotation=90)
plt.show()

# %%
profit_by_product = profit['Product Name'].value_counts().head(20)

plt.figure(figsize=(12,6))

profit_by_product.plot(kind='bar', color='orange')
plt.title('Top 20 Products with Most Profit-Making Sales')
plt.xlabel('Product Name')
plt.ylabel('Number of Profit-Making Sales')
plt.xticks(rotation=90)
plt.show()

# %%
# Correlation between discounts and profit
plt.figure(figsize=(8,6))
sns.scatterplot(x='Discount Amount', y='Profit', data=loss, alpha=0.6)
plt.title('Profit vs Discount Amount')
plt.xlabel('Discount Amount')
plt.ylabel('Profit')
plt.show()

# Calculate correlation coefficient
correlation = loss['Discount Amount'].corr(loss['Profit'])
print(f"Correlation between Discount Amount and Profit: {correlation:.2f}")
# Out:
# Correlation between Discount Amount and Profit: -0.27

# %%
loss_by_month = loss.groupby('Mth')['Profit'].count()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=loss_by_month.index, y=loss_by_month.values, palette='magma')
plt.title('Loss-Making Sales by Month')
plt.xlabel('Month')
plt.ylabel('Number of Loss-Making Sales')
plt.show()

# %%
numerical_data = ['Quantity', 'Bill Amount', 'Discount Amount','Overall Discount Amount', 'MRP','Purchase Price','Profit', 'Profit Margin']

df[numerical_data].describe()

# %%
loss.head()
# Out:
#             Unnamed: 0 Bill Number             BillTime  Customer Code  \
# Bill Date
# 2024-01-01           0   C01008600  Jan  1 2024  8:04AM            1.0
# 2024-01-01           1   C01008601  Jan  1 2024  8:29AM            0.0
# 2024-01-01           5   C01008603  Jan  1 2024 10:16AM           18.0
# 2024-01-01           6   C01008603  Jan  1 2024 10:16AM           18.0
# 2024-01-01           7   C01008603  Jan  1 2024 10:16AM           18.0
#
#                   Customer Name  No Of Days  Product Code       Product Name  \
# Bill Date
# 2024-01-01  THIRUCHENDUR MURUGA       182.0        3605.0       RANTAC 150MG
# 2024-01-01            MR.YUVESH       182.0       38752.0  PARACIP 650MG TAB
# 2024-01-01             MR.VIJAY       182.0       17173.0           NICIP MR
# 2024-01-01             MR.VIJAY       182.0       17280.0       CIPCAL 500MG
# 2024-01-01             MR.VIJAY       182.0        3051.0       HISTAC 150MG
#
# ...

# %%
plt.figure(figsize=(10,6))
corr = loss[['Net Amount', 'Profit', 'Discount Amount', 'Quantity']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10,6))
corr = profit[['Net Amount', 'Profit', 'Discount Amount', 'Quantity']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
df.head()
# Out:
#             Unnamed: 0 Bill Number             BillTime  Customer Code  \
# Bill Date
# 2024-01-01           0   C01008600  Jan  1 2024  8:04AM            1.0
# 2024-01-01           1   C01008601  Jan  1 2024  8:29AM            0.0
# 2024-01-01           2   C01008601  Jan  1 2024  8:29AM            0.0
# 2024-01-01           3   C01008602  Jan  1 2024  9:47AM           18.0
# 2024-01-01           4   C01008603  Jan  1 2024 10:16AM           18.0
#
#                   Customer Name  No Of Days  Product Code  \
# Bill Date
# 2024-01-01  THIRUCHENDUR MURUGA       182.0        3605.0
# 2024-01-01            MR.YUVESH       182.0       38752.0
# 2024-01-01            MR.YUVESH       182.0       12290.0
# 2024-01-01             MR.VIJAY       182.0        3515.0
# 2024-01-01             MR.VIJAY       182.0         214.0
#
#                         Product Name  Quantity  Bill Amount  ...  Sale Unit  \
# Bill Date                                                    ...
# ...
